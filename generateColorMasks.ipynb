# %%
# 01 VARS AND CONSTANTS
import random
import matplotlib
from operator import floordiv
nCircles = 25;
minDistance = 10;
containerRad = 250;
innerCircleRad = .30;

# %%
# 02 Init random number generator function
def getRandomArbitrary(min, max):
    return round(random.uniform(0, 1)* (max - min) + min);

# %%
# 03 FOR DEBUGGING:
# %qtconsole

# %%
# 04 Init color generator function
def generateColorsMaxMin(setSizeInput,minDistance, maxRelDistance, MaxDistance) :
    flagTest = 1 # the current state of affairs 

    while (flagTest == 1):
        Myarray = [0] * setSizeInput
        # Myarray = Array.from(Array(setSizeInput).keys());
        Myarray[0] = round(getRandomArbitrary(0, 359))

        for rr in range(0, len(Myarray)):

            #for(let rr = 1; rr < Myarray.length; rr++) {
            Myarray[rr] = round(getRandomArbitrary(+Myarray[rr-1] + minDistance, +Myarray[rr-1] + maxRelDistance))

            if (abs(max(Myarray) - min(Myarray)) > MaxDistance):
                flagTest = 1

            elif (abs(max(Myarray) - min(Myarray)) < MaxDistance):
                flagTest = 0
                
            elif Myarray[rr] - Myarray[0] < minDistance:
                flagTest = 1
                    #continue

                    # now shift 
                #for kk in Myarray:    
                for kk in range(0, len(Myarray)):
                        #for(let kk = 0; kk < Myarray.length; kk++):
                    if (Myarray[kk] > 360): 

                        Myarray[kk] = Myarray[kk] - 360


        if flagTest == 0:
                            #continue
                            #}
                            #shuffle and output
                         #   Myarray = random.shuffle(Myarray);
                        #Myarray

            return Myarray

# %%
# 05 Generate colors
mycolors = generateColorsMaxMin(nCircles,minDistance, 20, 359)
random.shuffle(mycolors);
mycolors
# Out:
# [210,
#  293,
#  158,
#  90,
#  33,
#  307,
#  139,
#  339,
#  175,
#  352,
#  225,
#  55,
#  200,
#  190,
#  11,
#  100,
#  43,
#  276,
#  243,
#  73,
#  121,
#  260,
#  323,
#  22,
#  110]

# %%
# 06 Wrap colors

for cc in range(0, len(mycolors)):
    if (mycolors[cc] > 359):
        mycolors[cc] = mycolors[cc] - 360
mycolors
# Out:
# [210,
#  293,
#  158,
#  90,
#  33,
#  307,
#  139,
#  339,
#  175,
#  352,
#  225,
#  55,
#  200,
#  190,
#  11,
#  100,
#  43,
#  276,
#  243,
#  73,
#  121,
#  260,
#  323,
#  22,
#  110]

# %%
# 07 Init rgb to hex functions

def rgb_to_hex(rgb):
    return '%02x%02x%02x' % rgb
#rgb_to_hex((myColors2))


def rgb_to_hex2(r, g, b):
  return ('{:X}{:X}{:X}').format(r, g, b)

def rgb_to_hex3(r,g,b):
    rgb = [r,g,b]
    x = ''
    for i in rgb:
        x += format(i,'02x').upper()
        if x[0] == x[1] and x[2] == x[3] and x[4] == x[5]:
            x = x[0] + x[2] + x[4]
            return '#'+x

# %%
# 08 Init colors list 

colorsList = [(0.9647,0.1451,0.4353),
(0.9647,0.1451,0.4314),
(0.9647,0.1451,0.4275),
(0.9647,0.1451,0.4216),
(0.9647,0.1451,0.4157),
(0.9647,0.1451,0.4098),
(0.9647,0.1451,0.4039),
(0.9647,0.1471,0.4000),
(0.9647,0.1490,0.3961),
(0.9647,0.1510,0.3902),
(0.9647,0.1529,0.3843),
(0.9647,0.1549,0.3784),
(0.9647,0.1569,0.3725),
            (243,39.5,123),
            (243,39,122),
            (243.5,38.5,120.5),
            (244,38,119),
            (244.5,37.5,118),
            (245,37,117),
            (245,37,115.5),
            (245,37,114),
            (245.5,37,112.5)]

# %%
# 10 Index rgb values associated with random colors picked

rgbVals2 = []
hexVals2 = []
rgbValsFull2 = []
for i in mycolors:
    rgbVals = (colorsList[i])
    rgbVals2.append(rgbVals)
    
    rgbValsFull = (colorsList2[i])
    rgbValsFull2.append(rgbValsFull)

# %%
# 11 Transform these values into strings and HEX for drawing circles

rgbStrings = []
hexStrings = []
for x in range(0, nCircles):
    string = rgbVals2[x]
    myStringHEX = (matplotlib.colors.to_hex(string))
    myStringRGB = 'rgb(' + str(rgbVals2[x][0]) +'/255, ' + str(rgbVals2[x][1]) +'/255, ' + str(rgbVals2[x][2]) +'/255)'


    rgbStrings.append(myStringRGB)
    hexStrings.append(myStringHEX)

# %%
# 12 Draw circles and save as svg

import numpy as np
from numpy.random import default_rng

rng = default_rng()

class Circle:
    """A little class representing an SVG circle."""

    def __init__(self, cx, cy, r, icolour=None):
        """Initialize the circle with its centre, (cx,cy) and radius, r.

        icolour is the index of the circle's colour.

        """
        self.cx, self.cy, self.r = cx, cy, r
        self.icolour = icolour

    def overlap_with(self, cx, cy, r):
        """Does the circle overlap with another of radius r at (cx, cy)?"""

        d = np.hypot(cx-self.cx, cy-self.cy)
        return d < r + self.r

    def draw_circle(self, fo):
        """Write the circle's SVG to the output stream, fo."""

        print('<circle cx="{}" cy="{}" r="{}" class="c{}"/>'
            .format(self.cx, self.cy, self.r, self.icolour), file=fo)

        # old rho_min=0.005
        # old rho_max=0.05,
class Circles:
    """A class for drawing circles-inside-a-circle."""
    #old n = 800
    #old rho_min=0.005,
    #old rho_max=0.05,
    #width = 600,
    def __init__(self, width=180, height=180, R=90, n=nCircles, rho_min=0.5,
                 rho_max=0.5, colours=hexStrings):
        """Initialize the Circles object.

        width, height are the SVG canvas dimensions
        R is the radius of the large circle within which the small circles are
        to fit.
        n is the maximum number of circles to pack inside the large circle.
        rho_min is rmin/R, giving the minimum packing circle radius.
        rho_max is rmax/R, giving the maximum packing circle radius.
        colours is a list of SVG fill colour specifiers to be referenced by
            the class identifiers c<i>. If None, a default palette is set.

        """

        self.width, self.height = width, height
        self.R, self.n = R, n
        # The centre of the canvas
        self.CX, self.CY = self.width // 2, self.height // 2
        self.rmin, self.rmax = R * rho_min, R * rho_max
        #self.colours = colours or [rgb(255, 255, 195),'#993300', '#a5c916', '#00AA66', '#FF9900']
        #self.colours = colours or ['rgb(255, 255, 195)','#993300', '#a5c916', '#00AA66', '#FF9900']
        #self.colours = colours or ['rgb(255/255, 0/255, 0/255)','rgb(0/255,0/255,255/255)']
        self.colours = colours or hexStrings
        #rgbStrings

    def preamble(self):
        """The usual SVG preamble, including the image size."""

        print('<?xml version="1.0" encoding="utf-8"?>\n'

        '<svg xmlns="http://www.w3.org/2000/svg"\n' + ' '*5 +
          'xmlns:xlink="http://www.w3.org/1999/xlink" width="{}" height="{}" >'
                .format(self.width, self.height), file=self.fo)

    def defs_decorator(func):
        """For convenience, wrap the CSS styles with the needed SVG tags."""

        def wrapper(self):
            print("""
            <defs>
            <style type="text/css"><![CDATA[""", file=self.fo)

            func(self)

            print("""]]></style>
            </defs>""", file=self.fo)
        return wrapper

    @defs_decorator
    def svg_styles(self):
        """Set the SVG styles: circles are coloured with no border."""

        print('circle {stroke: none;}', file=self.fo)
        for i, c in enumerate(self.colours):
            print('.c{} {{fill: {};}}'.format(i, c), file=self.fo)

    def make_svg(self, filename, *args, **kwargs):
        """Create the image as an SVG file with name filename."""

        ncolours = len(self.colours)
        with open(filename, 'w') as self.fo:
            self.preamble()
            self.svg_styles()
            for circle in self.circles:
                circle.draw_circle(self.fo)
            print('</svg>', file=self.fo)

    def _place_circle(self, r):
        # The guard number: if we don't place a circle within this number
        # of trials, we give up.
        guard = 500
        while guard:
            # Pick a random position, uniformly on the larger circle's interior
            cr, cphi = ( self.R * np.sqrt(np.random.random()),
                         2*np.pi * np.random.random() )
            cx, cy = cr * np.cos(cphi), cr * np.sin(cphi)
            if cr+r < self.R:
            # The circle fits inside the larger circle.
                if not any(circle.overlap_with(-10000, -10000, r)
                #if not any(circle.overlap_with(self.CX+cx, self.CY+cy, r)
                                    for circle in self.circles):
                    # The circle doesn't overlap any other circle: place it.
                    circle = Circle(cx+self.CX, cy+self.CY, r, 
                                #icolour=random.sample(len(self.colours), 1))  
                                #icolour=self.colours[0])
                                #icolour = i for i in range(self.n))
                                #icolour = [[i] for i in range(len(self.circles))])
                                #icolour= i for i in (self.n))
                                #icolour = self.colours[i])
                                #icolour=int(np.random.choice([1,2,3,4], size=1, replace=False, p=None)))
                                
                                #icolour = rng.choice(len(self.colours), size=1, replace=False))    
                                #icolour=np.random.randint(len(self.colours)))
                                #icolour = i)
                                icolour = len(self.circles))
                                #icolour = self.colours[len(self.circles)])
                                #icolour = self.colours[(self.n)-1])
                    
                                #icolour = i in range(self.n))
                    #print(icolour)
                    print(len(self.circles))
                    print(hexStrings[len(self.circles)])
                                #icolour = self.n[self.n])
                                
                                #icolour = len(self.circles))
                    
                    #print(icolour)
                    self.circles.append(circle)
                    return
            guard -= 1
        # Warn that we reached the guard number of attempts and gave up for
        # for this circle.
        print('guard reached.')

    def make_circles(self):
        """Place the little circles inside the big one."""

        # First choose a set of n random radii and sort them. We use
        # random.random() * random.random() to favour small circles.
        self.circles = []
        r = self.rmin + (self.rmax - self.rmin) * np.random.random(
                                self.n) * np.random.random(self.n)
        r[::-1].sort()
        # Do our best to place the circles, larger ones first.
        for i in range(self.n):
            #print(self.n)
            self._place_circle(r[i])

circles = Circles(n=nCircles)
circles.make_circles()
circles.make_svg('circles.svg')
# Out:
# 0
# #2e8d97
# 1
# #b462b7
# 2
# #5c8d51
# 3
# #b67213
# 4
# #ef3c45
# 5
# #ca54ad
# 6
# #758939
# 7
# #ed318a
# 8
# #468f69
# 9
# #f3277a
# 10
# #3b8aa7
# 11
# #de532c
# 12
# #2e8f8b
# 13
# #358f7e
# 14
# #f62760
# 15
# #a97814
# 16
# #e9473a
# 17
# #9771bd
# 18
# #5984b6
# 19
# #cb641c
# 20
# #8d8324
# 21
# #797bbd
# 22
# #de439d
# 23
# #f43053
# 24
# #9c7e1a
